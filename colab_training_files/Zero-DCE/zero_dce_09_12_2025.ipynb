# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/MyDrive/image-processing-2024-2025-deep-learning-based-models
# Out:
# /content/drive/MyDrive/image-processing-2024-2025-deep-learning-based-models

# %%
# !git clone https://github.com/Li-Chongyi/Zero-DCE.git
# Out:
# Cloning into 'Zero-DCE'...
# remote: Enumerating objects: 236, done.
# remote: Counting objects: 100% (236/236), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 236 (delta 43), reused 225 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (236/236), 30.89 MiB | 12.45 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Updating files: 100% (100/100), done.

# %%
cd Zero-DCE
# Out:
# /content/drive/MyDrive/image-processing-2024-2025-deep-learning-based-models/Zero-DCE

# %%
# Miniconda'yı indirip kur
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# Conda'nın Colab ortamına eklenmesi
import sys
sys.path.append('/usr/local/lib/python3.10/site-packages')

# Conda versiyonunu kontrol et
# !conda --version
# Out:
# --2025-12-09 09:05:53--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 157891003 (151M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 150.58M  56.9MB/s    in 2.6s
#
# 2025-12-09 09:05:56 (56.9 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [157891003/157891003]
#
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
# ...

# %%
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main

# %%
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r

# %% [markdown]
# It seems the `my_env` environment was not created after accepting the Terms of Service. Let's try creating it again.

# %%
# !conda create -n my_env python=3.7 -y
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.9.1
#     latest version: 25.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/my_env
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.12.2  |       h06a4308_0         125 KB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     pip-22.3.1                 |   py37h06a4308_0         2.7 MB
#     python-3.7.16              |       h7a1cb2a_0        44.8 MB
# ...

# %% [markdown]
# Now that the environment should be created, let's verify it and check the Python version inside it.

# %%
# !conda env list
# !conda run -n my_env python --version
# Out:
# # conda environments:
# #
# # *  -> active
# # + -> frozen
# base                     /usr/local
# my_env                   /usr/local/envs/my_env
#
# Python 3.7.16

# %%
# !conda run -n my_env pip install torch==1.10.0+cu102 torchvision==0.11.0+cu102 opencv-python -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.9/881.9 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 13.9 MB/s eta 0:00:00
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 19.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 88.4 MB/s eta 0:00:00
# ...
#   Using cached typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# ...

# %%
# !conda run -n my_env python Zero-DCE_code/lowlight_train.py --num_epochs 100 --display_iter 1 --num_workers 0 --lowlight_images_path train_data/
# Out:
# Total training examples: 2002
# Loss at iteration 1 : 1.4656740427017212
# Loss at iteration 2 : 1.6002122163772583
# Loss at iteration 3 : 0.9850177764892578
# Loss at iteration 4 : 1.2463808059692383
# Loss at iteration 5 : 1.1735796928405762
# Loss at iteration 6 : 1.5279616117477417
# Loss at iteration 7 : 1.8039634227752686
# Loss at iteration 8 : 1.688895344734192
# Loss at iteration 9 : 1.2772088050842285
# Loss at iteration 10 : 1.6876024007797241
# Loss at iteration 11 : 2.2479145526885986
# Loss at iteration 12 : 1.3635497093200684
# Loss at iteration 13 : 1.923387050628662
# Loss at iteration 14 : 1.6901744604110718
# Loss at iteration 15 : 1.5962612628936768
# Loss at iteration 16 : 1.686320185661316
# Loss at iteration 17 : 1.5627878904342651
# Loss at iteration 18 : 1.7407902479171753
# Loss at iteration 19 : 1.3754335641860962
# Loss at iteration 20 : 1.6429909467697144
# Loss at iteration 21 : 1.131106972694397
# Loss at iteration 22 : 1.432659387588501
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/image-processing-2024-2025-deep-learning-based-models/Zero-DCE

# %%
# !cd Zero-DCE_code && conda run -n my_env python lowlight_test.py --lowlight_images_path data/test_data/DICM
# Out:
# data/test_data/DICM/01.jpg
# 0.006566762924194336
# data/test_data/DICM/02.jpg
# 0.0017714500427246094
# data/test_data/DICM/03.jpg
# 0.0011882781982421875
# data/test_data/DICM/04.jpg
# 0.0011458396911621094
# data/test_data/DICM/05.jpg
# 0.0015900135040283203
# data/test_data/DICM/06.jpg
# 0.0011026859283447266
# data/test_data/DICM/07.jpg
# 0.0017077922821044922
# data/test_data/DICM/08.jpg
# 0.0014057159423828125
# data/test_data/DICM/09.jpg
# 0.001453399658203125
# data/test_data/DICM/10.jpg
# 0.0013518333435058594
# data/test_data/DICM/11.jpg
# 0.0011029243469238281
# data/test_data/DICM/12.jpg
# 0.0011875629425048828
# data/test_data/DICM/13.jpg
# 0.0011892318725585938
# data/test_data/DICM/14.jpg
# 0.0014109611511230469
# data/test_data/DICM/15.jpg
# 0.0012962818145751953
# data/test_data/DICM/16.jpg
# 0.001317739486694336
# data/test_data/DICM/17.jpg
# 0.0011801719665527344
# data/test_data/DICM/18.jpg
# 0.0012006759643554688
# data/test_data/DICM/19.jpg
# ...

# %% [markdown]
# Let's inspect the actual file structure within the `Zero-DCE` directory to understand why `data/test_data/` is not found. The current working directory is `/content/drive/MyDrive/image-processing-2024-2025-deep-learning-based-models/Zero-DCE`.

# %%
# !ls -R
# Out:
# .:
# Miniconda3-latest-Linux-x86_64.sh  snapshots   Zero-DCE_code   Zero-DCE.html
# README.md			   train_data  Zero-DCE_files
#
# ./snapshots:
# Epoch0.pth   Epoch25.pth  Epoch40.pth  Epoch56.pth  Epoch71.pth  Epoch87.pth
# Epoch10.pth  Epoch26.pth  Epoch41.pth  Epoch57.pth  Epoch72.pth  Epoch88.pth
# Epoch11.pth  Epoch27.pth  Epoch42.pth  Epoch58.pth  Epoch73.pth  Epoch89.pth
# Epoch12.pth  Epoch28.pth  Epoch43.pth  Epoch59.pth  Epoch74.pth  Epoch8.pth
# Epoch13.pth  Epoch29.pth  Epoch44.pth  Epoch5.pth   Epoch75.pth  Epoch90.pth
# Epoch14.pth  Epoch2.pth   Epoch45.pth  Epoch60.pth  Epoch76.pth  Epoch91.pth
# Epoch15.pth  Epoch30.pth  Epoch46.pth  Epoch61.pth  Epoch77.pth  Epoch92.pth
# Epoch16.pth  Epoch31.pth  Epoch47.pth  Epoch62.pth  Epoch78.pth  Epoch93.pth
# Epoch17.pth  Epoch32.pth  Epoch48.pth  Epoch63.pth  Epoch79.pth  Epoch94.pth
# Epoch18.pth  Epoch33.pth  Epoch49.pth  Epoch64.pth  Epoch7.pth	 Epoch95.pth
# ...
